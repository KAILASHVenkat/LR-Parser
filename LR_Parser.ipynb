# %% [markdown]
# <a href="https://colab.research.google.com/github/KAILASHVenkat/LR-Parser/blob/main/LR_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from google.colab import files
import os
from collections import Counter
import pyfiglet
import termtables as tt

# %%
# !pip install pyfiglet
# Out:
# Requirement already satisfied: pyfiglet in /usr/local/lib/python3.10/dist-packages (1.0.2)

# %%
# !pip install termtables
# Out:
# Requirement already satisfied: termtables in /usr/local/lib/python3.10/dist-packages (0.2.4)

# %%
print(pyfiglet.FigletFont.getFonts())
# Out:
# ['fourtops', 'threepoint', 'flower_power', 'yie_ar_k', 'tiles', 'demo_1__', 'radical_', 'r2-d2___', 'alligator2', 'xbrite', 'clb6x10', 'hypa_bal', 'relief2', 'epic', 'smshadow', 'atc_____', '3d-ascii', 'gauntlet', 'rozzo', 'colossal', 'sbookb', 'sbook', 'crazy', 'linux', 'skate_ro', 'banner4', 'tecrvs__', 'mayhem_d', 'charact5', 'green_be', 'stellar', 'catwalk', 'the_edge', 'horizontal_right', 'courbi', 'stforek', 'hades___', 'fbr2____', 'f15_____', 'line_blocks', '4max', 'top_duck', 'smtengwar', 'wow', 't__of_ap', 'acrobatic', 'stop', 'js_capital_curves', 'bear', 'mnemonic', 'times', 'druid___', '5x7', 'morse2', 'rot13', 'madrid', 'fire_font-s', 'dcs_bfmo', 'spliff', 'unarmed_', 'ansi_regular', 'bubble', 'benjamin', 'ti_pan__', 'characte', 'big', 'peaks', 'broadway', 'britebi', 'mcg_____', 'twisted', 'hollywood', 'standard', 'assalt_m', 'amc_slash', 'big_money-sw', 'big_money-se', 'wavy', 'clr8x8', 'invita', 'tsm_____', 'graceful', 'stacey', 'banner', 'clr5x8', 'braced', 'ghost_bo', 'block', 'rastan__', '5x8', 'filter', 'finalass', 'char1___', 'xhelvb', 'amc_untitled', 'triad_st', 'platoon2', 'modular', 'couri', 'goofy', 'e__fist_', 'hex', 'isometric3', 'tombstone', 'rampage_', 'pyramid', '1row', 'platoon_', 'future_3', 'letters', 'c_consen', 'magic_ma', 'script__', 'crawford2', 'npn_____', 'swan', 'c1______', 'fbr_stri', 'xcouri', 'sub-zero', 'gothic__', 'charact3', 'eftiwater', 'octal', 'georgi16', 'helvbi', 'smscript', 'varsity', 'tty', '3x5', 'letterw3', 'mini', 'bulbhead', 'xsbook', 'horizontal_left', 'stronger_than_all', 'brite', 'efti_robot', 'blocky', 'convoy__', 'sansb', 'funky_dr', 'xbriteb', 'odel_lak', 'xsans', 'asc_____', 'c2______', 'konto_slant', 'battle_s', 'small_poison', 'subteran', 'fp2_____', 'rally_sp', '5lineoblique', 'twopoint', 'a_zooloo', 'coil_cop', 'ascii_new_roman', 'stampate', 'bigfig', 'bell', 'xcour', 'ticks', 'clr5x6', 'katakana', 'sblood', 'ts1_____', 'dancing_font', 'clr7x8', 'usa_pq__', 'sketch_s', 'dotmatrix', 'xsansi', 'ripper!_', 'keyboard', 'caligraphy', 'broadway_kb', 'xsbookb', 'runyc', 'amc_razor2', 'tec_7000', 'gradient', '4x4_offr', 'future_4', 'kik_star', 'puzzle', 'charact6', 'charset_', 'hills___', 'larry3d', 'banner3', 'nscript', 'sbookbi', 'relief', 'rounded', 'notie_ca', 'xhelvi', 'bubble_b', 'big_money-ne', 'cygnet', '64f1____', 'rowancap', 'future_2', 'usaflag', 'isometric4', 'smisome1', 'arrows', 'thorned', 'nancyj-underlined', 'heroboti', 'rammstein', 'bubble__', 'short', 'xbritebi', 'future_1', 'rci_____', 'mad_nurs', 'js_block_letters', 'sbooki', "patorjk's_cheese", 'war_of_w', 'cour', 'gothic', 'ansi_shadow', 'alphabet', 'ticksslant', 'bright', 'clr6x10', 'grand_pr', 'poison', 'xchartr', 'konto', 'swamp_land', 'cursive', 'deep_str', 'tanja', 'clr6x6', 'star_strips', '3d_diagonal', 'amc_aaa01', 'new_asci', 'stampatello', 'sansbi', 'nipples', 'utopia', 'test1', 'dwhistled', 'chiseled', 'utopiai', 'demo_2__', 'fun_faces', 'xsansbi', 'jerusalem', 'clr6x8', 'chartri', 'future_7', 'o8', 'xcourb', 'nancyj', 'cricket', 'barbwire', 'kgames_i', 'timesofl', 'heart_right', 'script', 'home_pak', 'future_6', 'com_sen_', 'hyper___', 'cyberlarge', 'cards', 'z-pilot_', 'calvin_s', 'asslt__m', 'zone7___', 'shimrod', 'defleppard', 'usa_____', 'thin', 'mike', 'road_rai', 'bigchief', 'caus_in_', 'charact4', 'rad_____', 'thick', 'decimal', 'eftifont', 'lcd', 'mshebrew210', 'tec1____', 'ghoulish', 'stencil1', 'fantasy_', 'd_dragon', 'diamond', 'fairligh', 'sm______', 'js_stick_letters', 'js_cursive', 'outrun__', 'pepper', 'char3___', 'fair_mea', 'eftipiti', 'hieroglyphs', 'tinker-toy', 'stick_letters', 'slscript', 'alligator', 'this', 'baz__bil', 'drpepper', 'slide', 'advenger', 'slant_relief', 'mig_ally', 'etcrvs__', 'tengwar', 'alpha', 'helv', 'nancyj-fancy', 'smslant', 'phonix__', 'future_8', 'clb8x8', 'electronic', 'house_of', 'morse', 'twin_cob', 'lexible_', 'xhelvbi', 'future_5', 'tomahawk', 'eftirobot', 'helvb', 'inc_raw_', 'flyn_sh', 'xtty', 'fp1_____', 'chartr', 'kban', 'spc_demo', ' ...

# %%
result = pyfiglet.figlet_format("LR ( 0 ) Parser",font='graceful')
print(result)

def append_dot(a):
    jj = a.replace("->", "->.")
    return jj


def closure(a):
    temp = [a]
    for it in temp:
        jj = it[it.index(".") + 1]
        if jj != len(it) - 1:
            for k in prod:
                if k[0][0] == jj and (append_dot(k)) not in temp:
                    temp.append(append_dot(k))
        else:
            for k in prod:
                if k[0][0] == jj and it not in temp:
                    temp.append(it)

    return temp


def swap(new, pos):
    new = list(new)
    temp = new[pos]
    if pos != len(new):
        new[pos] = new[pos + 1]
        new[pos + 1] = temp
        new1 = "".join(new)
        return new1
    else:
        return "".join(new)


def goto1(x1):
    hh = []
    pos = x1.index(".")
    if pos != len(x1) - 1:
        jj = list(x1)
        kk = swap(jj, pos)
        if kk.index(".") != len(kk) - 1:
            jjj = closure(kk)
            return jjj
        else:
            hh.append(kk)
            return hh
    else:
        return x1


def get_terminals(gram):
    terms = set()
    for p in gram:
        x1 = p.split('->')
        for t in x1[1].strip():
            if not t.isupper() and t != '.' and t != '':
                terms.add(t)

    terms.add('$')

    return terms


def get_non_terminals(gram):
    terms = set()
    for p in gram:
        x1 = p.split('->')
        for t in x1[1].strip():
            if t.isupper():
                terms.add(t)

    return terms


def get_list(graph, state):
    final = []
    for g in graph:
        if int(g.split()[0]) == state:
            final.append(g)

    return final


if __name__ == '__main__':
    #This is where we define our grammar(Augmented grammar)
    prod = ['X->.S', 'S->AA', 'A->aA', 'A->b']
    set_of_items = []
    c = []


    print("---------------------------------------------------------------")
    print("Augmented Grammar")
    print(prod)

    prod_num = {}
    for i in range(1, len(prod)):
        prod_num[str(prod[i])] = i

    j = closure("X->.S")
    set_of_items.append(j)

    state_numbers = {}
    dfa_prod = {}
    items = 0
    while True:
        if len(set_of_items) == 0:
            break

        jk = set_of_items.pop(0)
        kl = jk
        c.append(jk)
        state_numbers[str(jk)] = items
        items += 1

        if len(jk) > 1:
            for item in jk:
                jl = goto1(item)
                if jl not in set_of_items and jl != kl:
                    set_of_items.append(jl)
                    dfa_prod[str(state_numbers[str(jk)]) + " " + str(item)] = jl
                else:
                    dfa_prod[str(state_numbers[str(jk)]) + " " + str(item)] = jl

    for item in c:
        for j in range(len(item)):
            if goto1(item[j]) not in c:
                if item[j].index(".") != len(item[j]) - 1:
                    c.append(goto1(item[j]))

    print("---------------------------------------------------------------")
    print("Total States: ", len(c))
    for i in range(len(c)):
        print(i, ":", c[i])
    print("---------------------------------------------------------------")

    dfa = {}
    for i in range(len(c)):
        if i in dfa:
            pass
        else:
            lst = get_list(dfa_prod, i)
            samp = {}
            for j in lst:
                s = j.split()[1].split('->')[1]
                search = s[s.index('.') + 1]
                samp[search] = state_numbers[str(dfa_prod[j])]

            if samp != {}:
                dfa[i] = samp

    table = []

    term = sorted(list(get_terminals(prod)))
    header = [''] * (len(term) + 1)
    header[(len(term) + 1) // 2] = 'Action'

    non_term = sorted(list(get_non_terminals(prod)))

    header2 = [''] * len(non_term)
    header2[(len(non_term)) // 2] = 'Goto'

    table.append([''] + term + non_term)

    table_dic = {}

    for i in range(len(c)):
        data = [''] * (len(term) + len(non_term))
        samp = {}

        # Action
        try:
            for j in dfa[i]:
                if not j.isupper() and j != '' and j != '.':
                    ind = term.index(j)
                    data[ind] = 'S' + str(dfa[i][j])
                    samp[term[ind]] = 'S' + str(dfa[i][j])

        except Exception:
            if i != 1:
                s = list(c[i][0])
                s.remove('.')
                s = "".join(s)
                lst = [i] + ['r' + str(prod_num[s])] * len(term)
                lst += [''] * len(non_term)
                table.append(lst)
                for j in term:
                    samp[j] = 'r' + str(prod_num[s])
            else:
                lst = [i] + [''] * (len(term) + len(non_term))
                lst[-1] = 'Accept'
                table.append(lst)

        # Goto
        try:
            for j in dfa[i]:
                if j.isupper():
                    ind = non_term.index(j)
                    data[len(term) + ind] = dfa[i][j]

                    samp[j] = str(dfa[i][j])

            table.append([i] + data)
        except Exception:
            pass

        if samp == {}:
            table_dic[i] = {'$': 'Accept'}
        else:
            table_dic[i] = samp

    final_table = tt.to_string(data=table, header=header + header2, style=tt.styles.ascii_thin_double, padding=(0, 1))

    print("\n")
    print(final_table)
    print("\n")

    # Parse String
    string = input("Enter the string to be parsed: ")
    string += '$'
    print("\n")

    stack = [0]
    pointer = 0

    # print(table_dic)

    header = ['Process', 'Look Ahead', 'Symbol', 'Stack']
    data = []

    i = 0
    accepted = False
    while True:
        try:
            try:
                prods = dfa[stack[-1]]
                prod_i = prods[string[i]]  # state num
            except Exception:
                prod_i = None

            try:
                tab = table_dic[stack[-1]]
                tab_i = tab[string[i]]  # S or r
            except Exception:
                tab = table_dic[stack[-2]]
                tab_i = tab[stack[-1]]  # S or r

            if tab_i == 'Accept':
                data.append(['Action({0}, {1}) = {2}'.format(stack[-1], string[i], tab_i), i, string[i], str(stack)])
                accepted = True
                break
            else:
                if tab_i[0] == 'S' and not str(stack[-1]).isupper():
                    lst = ['Action({0}, {1}) = {2}'.format(stack[-1], string[i], tab_i), i, string[i]]
                    stack.append(string[i])
                    stack.append(prod_i)
                    lst.append(str(stack))
                    data.append(lst)
                    i += 1
                elif tab_i[0] == 'r':
                    lst = ['Action({0}, {1}) = {2}'.format(stack[-1], string[i], tab_i), i, string[i]]
                    x = None
                    for i1 in prod_num:
                        if prod_num[i1] == int(tab_i[1]):
                            x = i1
                            break

                    length = 2 * (len(x.split('->')[1]))
                    for _ in range(length):
                        stack.pop()

                    stack.append(x[0])
                    lst.append(str(stack))
                    data.append(lst)
                else:
                    lst = ['goto({0}, {1}) = {2}'.format(stack[-2], stack[-1], tab_i), i, string[i]]
                    stack.append(int(tab_i))
                    lst.append(str(stack))
                    data.append(lst)
        except Exception:
            accepted = False
            break

    try:
        parsing_table = tt.to_string(data=data, header=header, style=tt.styles.ascii_thin_double, padding=(0, 1))
        print(parsing_table)
        if accepted:
            string = string[:-1]
            print(f"\n\n")
            print("The string {0} is parsable!".format(string))
            print(f"\n\n")
        else:
            print("The string {0} is not parsable!".format(string))
            print(f"\n\n")
    except Exception:
        print("Invalid string entered!")
# Out:
#  __    ____     _     __     _     ____   __   ____  ____  ____  ____
# (  )  (  _ \   / )   /  \   ( \   (  _ \ / _\ (  _ \/ ___)(  __)(  _ \
# / (_/\ )   /  ( (   (  0 )   ) )   ) __//    \ )   /\___ \ ) _)  )   /
# \____/(__\_)   \_)   \__/   (_/   (__)  \_/\_/(__\_)(____/(____)(__\_)
#
# ---------------------------------------------------------------
# Augmented Grammar
# ['X->.S', 'S->AA', 'A->aA', 'A->b']
# ---------------------------------------------------------------
# Total States:  7
# 0 : ['X->.S', 'S->.AA', 'A->.aA', 'A->.b']
# 1 : ['X->S.']
# 2 : ['S->A.A', 'A->.aA', 'A->.b']
# 3 : ['A->a.A', 'A->.aA', 'A->.b']
# 4 : ['A->b.']
# 5 : ['S->AA.']
# 6 : ['A->aA.']
# ---------------------------------------------------------------
#
#
# +---+----+--------+----+---+--------+
# |   |    | Action |    |   | Goto   |
# +===+====+========+====+===+========+
# |   | $  | a      | b  | A | S      |
# +---+----+--------+----+---+--------+
# | 0 |    | S3     | S4 | 2 | 1      |
# +---+----+--------+----+---+--------+
# | 1 |    |        |    |   | Accept |
# +---+----+--------+----+---+--------+
# | 2 |    | S3     | S4 | 5 |        |
# +---+----+--------+----+---+--------+
# | 3 |    | S3     | S4 | 6 |        |
# +---+----+--------+----+---+--------+
# | 4 | r3 | r3     | r3 |   |        |
# +---+----+--------+----+---+--------+
# | 5 | r1 | r1     | r1 |   |        |
# +---+----+--------+----+---+--------+
# | 6 | r2 | r2     | r2 |   |        |
# +---+----+--------+----+---+--------+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-af4dc57ce5c7> in <cell line: 86>()
#     218
#     219     # Parse String
# --> 220     string = input("Enter the string to be parsed: ")
#     221     string += '$'
#     222     print("\n")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
